# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
from openpyxl import Workbook
from openpyxl import load_workbook
import math
import smtplib
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
sender = "charlasvocacionalesmorus@gmail.com"
password = str(input())
# Out:
# calciferinformatica

# %%
data = pd.read_excel("Formulario inscripción a charlas vocacionales (Respuestas).xlsx", sheet_name="Respuestas de formulario 1")
data = data.drop(columns=['Marca temporal', "Instrucción de yoga - Miércoles 29 de Septiembre de 15 a 16 hrs. ",
                         'Arquitectura - Lunes 27 de Septiembre de 16 a 17 hrs',
                          'Educación - Lunes 27  de Septiembre de 19  a 20 hrs. ', 
                          'Desarrollo sustentable - Lunes 27 de Septiembre de 15 a 16hrs. ', 
                          'Ingeniería civil industrial - Lunes 27 de Septiembre de 18 a 19 hrs'
                         ])
opciones = list(data.columns)

#print(opciones)

print(data.shape)

filas = data.shape[0]
columnas = data.shape[1]


correoActividad = []

for persona in range(0, filas):
    count = 0
    confirmados = []
    
    for i in data.iloc[persona]:
        #print(i)
        if i=="Confirmar asistencia":
            confirmados.append([data.iloc[persona][0],opciones[count]])
        count +=1
    correoActividad.append(confirmados)

print(correoActividad)


#print(opciones.columns)
# Out:
# (75, 14)
# ...

# %%
data = pd.read_excel("Formulario inscripción a charlas vocacionales (Respuestas).xlsx", sheet_name="Respuestas de formulario 1")

data = data.drop(columns=['Marca temporal', "Instrucción de yoga - Miércoles 29 de Septiembre de 15 a 16 hrs. ",
                         'Arquitectura - Lunes 27 de Septiembre de 16 a 17 hrs',
                          'Educación - Lunes 27  de Septiembre de 19  a 20 hrs. ', 
                          'Desarrollo sustentable - Lunes 27 de Septiembre de 15 a 16hrs. ', 
                          'Ingeniería civil industrial - Lunes 27 de Septiembre de 18 a 19 hrs'
                         ])
opciones = list(data.columns)




filas = data.shape[0]
columnas = data.shape[1]


correoActividad = {}

for persona in range(0, filas):
    count = 0
   
    correoActividad[data.iloc[persona][0]]= []
    
    
    
    for i in data.iloc[persona]:
        #print(i)
        if i=="Confirmar asistencia":
            correoActividad[data.iloc[persona][0]].append( opciones[count])
        count +=1
    #correoActividad.append(datosIndividuales)

#print(correoActividad)
pp.pprint(correoActividad)
# Out:
# {   'Mprades@dsmorus.cl': [   'Medicina (Especialidad: Neurología pediátrica) '
#                               '- Martes 28 de Septiembre de 18 a 19 hrs. '],
#     'aaliaga@dsmorus.cl': [   'Ingeniería comercial - Miércoles 29 de '
#                               'Septiembre de 19 a 20 hrs. '],
#     'abarcelo@dsmorus.cl': [   'Servicio a Bordo Aerolínea - Miércoles 29 de '
#                                'Septiembre de 15 a 16 hrs. (¡mismo horario de '
#                                'la charla anterior!)',
#                                'Ingeniería comercial - Miércoles 29 de '
#                                'Septiembre de 19 a 20 hrs. '],
#     'adezerega@dsmorus.cl': [],
#     'agutierrez@dsmorus.cl': [   'Medicina (Especialidad: Neurología '
#                                  'pediátrica) - Martes 28 de Septiembre de 18 '
#                                  'a 19 hrs. ',
#                                  'Medicina (especialidad: coloproctología) - '
# ...

# %%
def uwuawa(c):
    if c =="Bioquímica - Miércoles 29 de Septiembre de 18 a 19 hrs":
        return "Bioquímica, Miércoles 29, 18 a 19 hrs"
    if c =="Construcción civil - Jueves 30 de Septiembre de 16 a 17 hrs. ":
        return "Construcción civil, Jueves 30, 16 a 17 hrs. "
    if c =="Arqueología - Martes 28 de Septiembre de 16 a 17 hrs.":
        return "Arqueología, Martes 28, 16 a 17 hrs."
    if c =="Derecho - Martes 28 de Septiembre de 19 a 20 hrs. ":
        return "Derecho, Martes 28, 19 a 20 hrs. "
    if c =="Geología y geofísica - Jueves 30 de Septiembre de 18 a 19 hrs. ":
        return "Geología, Jueves 30, 18 a 19 hrs. "
    if c =="Ingeniería comercial - Miércoles 29 de Septiembre de 19 a 20 hrs. ":
        return "Ingeniería comercial, Miércoles 29, 19 a 20 hrs. "
    if c =="Literatura - Martes 28 de Septiembre de 17 a 18 hrs. ":
        return "Literatura, Martes 28, 17 a 18 hrs. "
    if c =="Medicina (Especialidad: Neurología pediátrica) - Martes 28 de Septiembre de 18 a 19 hrs. ":
        return "Medicina (Neurología pediátrica), Martes 28, 18 a 19 hrs. "
    if c =="Medicina (especialidad: coloproctología) - Jueves 30 de Septiembre de 15 a 16 hrs":
        return "Medicina (coloproctología), Jueves 30, 15 a 16 hrs"
    if c =="Química farmacéutica - Jueves 30 de Septiembre de 17 a 18 hrs":
        return "Química farmacéutica, Jueves 30, 17 a 18 hrs"
    if c =="Servicio a Bordo Aerolínea - Miércoles 29 de Septiembre de 15 a 16 hrs. (¡mismo horario de la charla anterior!)":
        return "Servicio a Bordo Aerolínea, Miércoles 29, 15 a 16 hrs."
    if c =="Sociedad civil - Miércoles 29 de Septiembre de 16 a 17 hrs. ":
        return "Sociedad civil, Miércoles 29, 16 a 17 hrs. "
    if c =="Sociología - Jueves 30 de Septiembre de 19 a 20 hrs. ":
        return "Sociología, Jueves 30, 19 a 20 hrs. "





listaActividades = list(data.drop(columns = ["Dirección de correo electrónico"]).columns)
#pp.pprint(linksZoom)
mailsZoom = {}
linksZoom = { 'Arqueología - Martes 28 de Septiembre de 16 a 17 hrs.': 'https://us06web.zoom.us/j/6327660757',
    
    'Bioquímica - Miércoles 29 de Septiembre de 18 a 19 hrs': 'https://us02web.zoom.us/j/6377471655',
    'Construcción civil - Jueves 30 de Septiembre de 16 a 17 hrs. ': 'https://us02web.zoom.us/j/6377471655',
    'Derecho - Martes 28 de Septiembre de 19 a 20 hrs. ': 'https://us02web.zoom.us/j/6377471655 ',
    'Geología y geofísica - Jueves 30 de Septiembre de 18 a 19 hrs. ': 'https://us02web.zoom.us/j/6377471655',
    'Ingeniería comercial - Miércoles 29 de Septiembre de 19 a 20 hrs. ': 'https://us06web.zoom.us/j/6327660757 ',
    'Literatura - Martes 28 de Septiembre de 17 a 18 hrs. ': 'https://us02web.zoom.us/j/6377471655',
    'Medicina (Especialidad: Neurología pediátrica) - Martes 28 de Septiembre de 18 a 19 hrs. ': 'https://us06web.zoom.us/j/6327660757',
    'Medicina (especialidad: coloproctología) - Jueves 30 de Septiembre de 15 a 16 hrs': 'https://us06web.zoom.us/j/6327660757',
    'Química farmacéutica - Jueves 30 de Septiembre de 17 a 18 hrs': 'https://us06web.zoom.us/j/6327660757 ',
    'Servicio a Bordo Aerolínea - Miércoles 29 de Septiembre de 15 a 16 hrs. (¡mismo horario de la charla anterior!)': 'https://us02web.zoom.us/j/6377471655',
    'Sociedad civil - Miércoles 29 de Septiembre de 16 a 17 hrs. ': 'https://us06web.zoom.us/j/6327660757',
    'Sociología - Jueves 30 de Septiembre de 19 a 20 hrs. ': 'https://us06web.zoom.us/j/6327660757 '}
for actividad in listaActividades:
    mailsZoom[actividad]=[]

for persona in correoActividad.keys():
    for actividad in correoActividad[persona]:
        mailsZoom[actividad].append(persona)

pp.pprint(mailsZoom)
# Out:
# {   'Arqueología - Martes 28 de Septiembre de 16 a 17 hrs.': [   'aschmohl@dsmorus.cl',
#                                                                  'gcoll@dsmorus.cl',
#                                                                  'mschmidt@dsmorus.cl',
#                                                                  'mtorres@dsmorus.cl',
#                                                                  'blara@dsmorus.cl',
#                                                                  'cmontes@dsmorus.cl'],
#     'Bioquímica - Miércoles 29 de Septiembre de 18 a 19 hrs': [   'wstudemann@gmail.com',
#                                                                   'nikolas.farina@gmail.com',
#                                                                   'rsalinas@dsmorus.cl',
#                                                                   'vdiaz@dsmorus.cl',
#                                                                   'rwagner@dsmorus.cl',
# ...

# %%
from email.message import EmailMessage

server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(sender,password)
print("Success")


count =0 

for actividad in mailsZoom.keys():
    for persona in mailsZoom[actividad]:
        if count>87:
            m = EmailMessage()
            m['Subject'] = "Links charlas vocacionales"
            m['To'] = persona
            m['From'] = "charlasvocacionalesmorus@gmail.com"

            m.add_alternative(f"""\
            <!DOCTYPE html>
            <html>
                <body>

                    Actividad: {uwuawa(actividad)}\n
                    Link:{linksZoom[actividad]}
                    ¡Esperamos verte en la charla!
                    Atte.
                    CAA y CPA
                </body>
            </html>



            """, subtype='html')



            server.send_message(m)
            print(count)
            
            print("sent")
        count+=1
    
print("listo")
# Out:
# Success
# 88
# sent
# 89
# sent
# 90
# sent
# 91
# sent
# 92
# sent
# 93
# sent
# 94
# sent
# 95
# sent
# 96
# sent
# 97
# sent
# 98
# sent
# 99
# sent
# 100
# sent
# 101
# sent
# 102
# sent
# 103
# sent
# 104
# sent
# 105
# sent
# 106
# sent
# 107
# sent
# 108
# sent
# 109
# sent
# 110
# sent
# 111
# sent
# 112
# sent
# 113
# sent
# 114
# sent
# 115
# sent
# 116
# sent
# 117
# sent
# 118
# sent
# 119
# sent
# 120
# sent
# 121
# sent
# 122
# sent
# 123
# sent
# 124
# sent
# 125
# sent
# 126
# sent
# 127
# sent
# 128
# sent
# 129
# sent
# 130
# sent
# 131
# sent
# 132
# sent
# 133
# sent
# 134
# sent
# 135
# sent
# 136
# sent
# 137
# sent
# 138
# sent
# 139
# sent
# 140
# sent
# 141
# sent
# listo

# %%
receiver = "benjaoyama@gmail.com"
subject = "Links charlas vocacionales"

body = "Estos son los links de las charlas a las que te inscribiste para esta semana: "
message =f"""Subject: {subject}\n\n
{body}
"""





server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(sender,password)

print("Success")
server.sendmail(sender, receiver, message)
print("sent")
# Out:
# Success
# sent
