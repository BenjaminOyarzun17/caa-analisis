# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
from openpyxl import Workbook
from openpyxl import load_workbook

import math
import smtplib
from email.message import EmailMessage

import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
sender = "charlasvocacionalesmorus@gmail.com"
password = str(input())
# Out:
# calciferinformatica

# %%
data = pd.read_excel("Semana 2 (Respuestas).xlsx", sheet_name="Respuestas de formulario 1")
data = data.drop(columns=['Marca temporal', "Relaciones públicas - Martes 5 de Octubre de 18 a 19 hrs."
                          
                         ])

opciones = list(data.columns)



filas = data.shape[0]
columnas = data.shape[1]

correoActividad = {}

for persona in range(0, filas):
    count = 0
   
    correoActividad[data.iloc[persona][0]]= []
    
    
    
    for i in data.iloc[persona]:
        #print(i)
        if i=="Confirmar asistencia":
            correoActividad[data.iloc[persona][0]].append( opciones[count])
        count +=1
    #correoActividad.append(datosIndividuales)

#print(correoActividad)
pp.pprint(correoActividad)
correos = correoActividad
print(correos.keys())
print(data.shape)
# Out:
# {   'aaliaga@dsmorus.cl': [   'Economía e Ing. Civil Industrial - Lunes 4 de '
#                               'Octubre de 15 a  16hrs. ',
#                               'Ing. Civil en Minas - Lunes 4 de Octubre de 19 '
#                               'a 20 hrs. (mismo horario que la anterior)',
#                               'Ingeniería civil - Miércoles 6 de Octubre de 15 '
#                               'a 16 hrs (mismo horario de la anterior). ',
#                               'Ing. Civil Química e Industrial - Viernes 8 de '
#                               'Octubre de 18 a 19 hrs. '],
#     'abarcelo@dsmorus.cl': [   'Economía e Ing. Civil Industrial - Lunes 4 de '
#                                'Octubre de 15 a  16hrs. ',
#                                'Ing. Civil en Computación, eléctrica y '
#                                'electrónica - Martes 5 de Octubre de 17 a 18 '
#                                'hrs.',
# ...

# %%
def FormaAActividad(c):
    if c =="Economía e Ing. Civil Industrial - Lunes 4 de Octubre de 15 a  16hrs. ":
        return "Economía; Ing. Civil Industrial. Lunes 4, 15 a 16 hrs."
    if c =="Odontología - Lunes 4 de Octubre de 16 a 17 hrs. ":
        return "Odontología. Lunes 4, 16 a 17 hrs."
    if c =="Derecho- Lunes 4 de Octubre de 17 a 18 hrs. ":
        return "Derecho. Lunes 4, 17 a 18 hrs."

    if c =="Astronomía - Lunes 4 de Octubre de 18 a 19 hrs. ":
        return "Astronomía. Lunes 4, 18 a 19 hrs."

    if c =="Trabajo social- Lunes 4 de Octubre de 19 a 20 hrs. ":
        return "Trabajo social. Lunes 4, 19 a 20 hrs."

    if c =="Ing. Civil en Minas - Lunes 4 de Octubre de 19 a 20 hrs. (mismo horario que la anterior)":
        return "Ing. Civil en Minas. Lunes 4, 19 a 20 hrs."

    if c =="Ing. Agrónoma - Ciencias políticas y su aplicación en políticas públicas - Martes 5 de Octubre de 15 a 16 hrs.":
        return "Ing. Agrónoma - Ciencias políticas en políticas públicas. Martes 5, 15 a 16 hrs."

    if c =="Arte y expresión urbana - Martes 5 de Octubre de 16 a 17 hrs.":
        return "Arte y expresión urbana. Martes 5, 16 a 17 hrs."

    if c =="Ing. Civil en Computación, eléctrica y electrónica - Martes 5 de Octubre de 17 a 18 hrs.":
        return "Ing. Civil en Computación, eléctrica y electrónica. Martes 5, 17 a 18 hrs."

    if c =="Sonido - Música, Composición y Producción - Martes 5 de Octubre de 19 a 20 hrs.":
        return "Sonido - Música, Composición y Producción. Martes 5, 19 a 20 hrs."

    if c =="Filosofía - Miércoles 6 de Octubre de 15 a 16 hrs. ":
        return "Filosofía. Miércoles 6, 15 a 16 hrs."
    if c =="Ingeniería civil - Miércoles 6 de Octubre de 15 a 16 hrs (mismo horario de la anterior). ":
        return "Ingeniería civil. Miércoles 6, 15 a 16 hrs."

    if c =="Psicología - Miércoles 6 de Octubre de 17 a 18 hrs. ":
        return "Psicología, Miércoles 6, 17 a 18 hrs."

    if c =="Veterinaria - Miércoles 6 de Octubre de 18 a 19 hrs. ":
        return "Veterinaria, Miércoles 6, 18 a 19 hrs."

    if c =="Asesoría de estudios en Alemania - Miércoles 6 de Octubre de 19 a 20 hrs. ":
        return "Asesoría de estudios en Alemania, Miércoles 6, 19 a 20 hrs."
    
    if c =="Enfermería - Jueves 7 de Octubre de 15 a 16 hrs. ":
        return "Enfermería, Jueves 7, 15 a 16 hrs."
    
    if c =="Política [Germán Becker (embajador chileno en Panamá), Maya Fernandez (diputada), Giorgio Jackson (diputado), Ricardo Lagos (senador)]  - Jueves 7 de Octubre de 17 a 18 hrs.":
        return "Política, Jueves 7, 17 a 18 hrs."
    
    if c =="Historia - Jueves 7 de Octubre de 19 a 20 hrs. ":
        return "Historia, Jueves 7, 19 a 20 hrs."

    if c =="Derecho - Viernes 8 de Octubre de 15 a 16 hrs. ":
        return "Derecho, Viernes 8, 15 a 16 hrs."
    
    if c =="Técnico mecánico - Viernes 8 de Octubre de 16 a 17 hrs. ":
        return "Técnico mecánico, Viernes 8, 16 a 17 hrs.  "
    if c =="Ing. Civil Química e Industrial - Viernes 8 de Octubre de 18 a 19 hrs. ":
        return "Ing. Civil Química e Industrial, Viernes 8, 18 a 19 hrs.  "
    if c =="Kinesiología - Viernes 8 de Octubre de 18 a 19 hrs. (mismo horario de la anterior) ":
        return "Kinesiología, Viernes 8, 18 a 19 hrs. "
    if c =="Diseño - Viernes 8 de Octubre de 19 a 20 hrs. ":
        return "Diseño, Viernes 8, 19 a 20 hrs.  "

# %%
listaActividades = list(data.drop(columns = ["Dirección de correo electrónico"]).columns)
#pp.pprint(linksZoom)
mailsZoom = {}
linksZoom = {"Economía e Ing. Civil Industrial - Lunes 4 de Octubre de 15 a  16hrs. ":"https://us02web.zoom.us/j/6377471655",
            "Odontología - Lunes 4 de Octubre de 16 a 17 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Derecho- Lunes 4 de Octubre de 17 a 18 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Astronomía - Lunes 4 de Octubre de 18 a 19 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Trabajo social- Lunes 4 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Ing. Civil en Minas - Lunes 4 de Octubre de 19 a 20 hrs. (mismo horario que la anterior)":"https://us06web.zoom.us/j/6327660757",
             "Ing. Agrónoma - Ciencias políticas y su aplicación en políticas públicas - Martes 5 de Octubre de 15 a 16 hrs.":"https://us02web.zoom.us/j/6377471655",
             "Arte y expresión urbana - Martes 5 de Octubre de 16 a 17 hrs.":"https://us06web.zoom.us/j/6327660757",
             "Ing. Civil en Computación, eléctrica y electrónica - Martes 5 de Octubre de 17 a 18 hrs.":"https://us02web.zoom.us/j/6377471655",
             "Sonido - Música, Composición y Producción - Martes 5 de Octubre de 19 a 20 hrs.":"https://us06web.zoom.us/j/6327660757",
             "Filosofía - Miércoles 6 de Octubre de 15 a 16 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Ingeniería civil - Miércoles 6 de Octubre de 15 a 16 hrs (mismo horario de la anterior). ":"https://us06web.zoom.us/j/6327660757",
             "Psicología - Miércoles 6 de Octubre de 17 a 18 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Veterinaria - Miércoles 6 de Octubre de 18 a 19 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Asesoría de estudios en Alemania - Miércoles 6 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Enfermería - Jueves 7 de Octubre de 15 a 16 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Política [Germán Becker (embajador chileno en Panamá), Maya Fernandez (diputada), Giorgio Jackson (diputado), Ricardo Lagos (senador)]  - Jueves 7 de Octubre de 17 a 18 hrs.":"https://us06web.zoom.us/j/6327660757",
             "Historia - Jueves 7 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Derecho - Viernes 8 de Octubre de 15 a 16 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Técnico mecánico - Viernes 8 de Octubre de 16 a 17 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Ing. Civil Química e Industrial - Viernes 8 de Octubre de 18 a 19 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Kinesiología - Viernes 8 de Octubre de 18 a 19 hrs. (mismo horario de la anterior) ":"https://us06web.zoom.us/j/6327660757",
             "Diseño - Viernes 8 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655"
             
            }
for actividad in listaActividades:
    mailsZoom[actividad]=[]

for persona in correoActividad.keys():
    for actividad in correoActividad[persona]:
        mailsZoom[actividad].append(persona)

pp.pprint(mailsZoom)
# Out:
# {   'Arte y expresión urbana - Martes 5 de Octubre de 16 a 17 hrs.': [   'vmaldonado@dsmorus.cl',
#                                                                          'masepulveda@dsmorus.cl',
#                                                                          'mcrignola@dsmorus.cl',
#                                                                          'msoto@dsmorus.cl',
#                                                                          'emonsalve@dsmorus.cl',
#                                                                          'edunner@dsmorus.cl',
#                                                                          'cmontes@dsmorus.cl',
#                                                                          'vgonzalez@dsmorus.cl'],
#     'Asesoría de estudios en Alemania - Miércoles 6 de Octubre de 19 a 20 hrs. ': [   'avillagra@dsmorus.cl',
# ...

# %%
linksZoom = {"Economía e Ing. Civil Industrial - Lunes 4 de Octubre de 15 a  16hrs. ":"https://us02web.zoom.us/j/6377471655",
            "Odontología - Lunes 4 de Octubre de 16 a 17 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Derecho- Lunes 4 de Octubre de 17 a 18 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Astronomía - Lunes 4 de Octubre de 18 a 19 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Trabajo social- Lunes 4 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Ing. Civil en Minas - Lunes 4 de Octubre de 19 a 20 hrs. (mismo horario que la anterior)":"https://us06web.zoom.us/j/6327660757",
             "Ing. Agrónoma - Ciencias políticas y su aplicación en políticas públicas - Martes 5 de Octubre de 15 a 16 hrs.":"https://us02web.zoom.us/j/6377471655",
             "Arte y expresión urbana - Martes 5 de Octubre de 16 a 17 hrs.":"https://us06web.zoom.us/j/6327660757",
             "Ing. Civil en Computación, eléctrica y electrónica - Martes 5 de Octubre de 17 a 18 hrs.":"https://us02web.zoom.us/j/6377471655",
             "Sonido - Música, Composición y Producción - Martes 5 de Octubre de 19 a 20 hrs.":"https://us06web.zoom.us/j/6327660757",
             "Filosofía - Miércoles 6 de Octubre de 15 a 16 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Ingeniería civil - Miércoles 6 de Octubre de 15 a 16 hrs (mismo horario de la anterior). ":"https://us06web.zoom.us/j/6327660757",
             "Psicología - Miércoles 6 de Octubre de 17 a 18 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Veterinaria - Miércoles 6 de Octubre de 18 a 19 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Asesoría de estudios en Alemania - Miércoles 6 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Enfermería - Jueves 7 de Octubre de 15 a 16 hrs. ":"https://us02web.zoom.us/j/6377471655",
             FALTA EL LINK DE POLITICA
             
             "Política [Germán Becker (embajador chileno en Panamá), Maya Fernandez (diputada), Giorgio Jackson (diputado), Ricardo Lagos (senador)]  - Jueves 7 de Octubre de 17 a 18 hrs.":"",
             "Historia - Jueves 7 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Derecho - Viernes 8 de Octubre de 15 a 16 hrs. ":"https://us06web.zoom.us/j/6327660757",
             "Técnico mecánico - Viernes 8 de Octubre de 16 a 17 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Ing. Civil Química e Industrial - Viernes 8 de Octubre de 18 a 19 hrs. ":"https://us02web.zoom.us/j/6377471655",
             "Kinesiología - Viernes 8 de Octubre de 18 a 19 hrs. (mismo horario de la anterior) ":"https://us06web.zoom.us/j/6327660757",
             "Diseño - Viernes 8 de Octubre de 19 a 20 hrs. ":"https://us02web.zoom.us/j/6377471655"
             
            }

# %%
from email.message import EmailMessage

server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(sender,password)
print("Success")


count =0 

for actividad in mailsZoom.keys():
    for persona in mailsZoom[actividad]:
        if "Política" in FormaAActividad(actividad) :
            m = EmailMessage()
            m['Subject'] = "Recordatorio charlas de hoy"
            m['To'] = persona
            m['From'] = "charlasvocacionalesmorus@gmail.com"

            m.add_alternative(f"""\
            <!DOCTYPE html>
            <html>
                <body>
                    <p>
                    Actividad: {FormaAActividad(actividad)}

                    </p>
                    <p>
                        Link:{linksZoom[actividad]}
                    </p>
                    <p>
                    ¡Esperamos verte en la charla!
                    </p>
                    <p>
                        Atte.

                    </p>
                    <p>
                    CAA y CPA
                    </p>

                </body>
            </html>



            """, subtype='html')


            
            server.send_message(m)
            print(count)
            #print(FormaAActividad(actividad))
        
        
        count+=1
    
print("listo")
# Out:
# Success
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# listo
