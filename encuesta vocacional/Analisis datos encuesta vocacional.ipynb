# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
from openpyxl import Workbook
from openpyxl import load_workbook

# %%
data = pd.read_excel("Encuesta Vocacional.xlsx", sheet_name="Respuestas de formulario 1")


dicSaludYCCNN ={
    
    "medicina":0,
    "veterinaria":0,
    "geologia":0,
    "química":0,
    "nutrición":0,
    "física":0,
    "biología":0,
    "odontología":0,
    "obstetricia":0,
    "enfermería":0,
    "astronomía":0,
    "obstetricia":0   
    
}






dicCarreras = {
    "medicina":0, #med
    "ingeniería":0,  #ingen
    "arte":0,  #arte
    "teatro":0,  #teat
    "veterinaria":0,  #vete
    "geologia":0, #geolo
    "ciencias sociales":0,  #social
    "química":0,  #quími
    "arqueología":0, #arqueo
    "psicología":0,  #psico
    "arquitectura":0, #arqui
    "derecho":0, #dere
    "economía":0, #econo
    "biología":0, #bio
    "astronomia":0, #astro
    "enfermería":0, #enfer
    "pedagogía":0, #peda
    "antropologia":0, #antropo
    "periodismo":0, #period
    "historia":0, #histo
    "filosofía":0,    #filo
    "física":0,    #filo
    "marketing":0,
    "nutrición":0,
    "ciencias políticas":0,
    "odontologia":0,
    "diseño":0,
    "literatura":0,
    "piloto":0, 
    "sociología":0,
    "obstetricia":0
}

carreras = []
tecnicas = []
ejercito = []
oficios = []

for i in data["Carrera 1"]:
    if (type(i) != float):    
        carreras.append(i.lower())


for i in data["Carrera 2"]:
    if (type(i) != float):    
        carreras.append(i.lower())

for i in data["Carrera 3"]:
    if (type(i) != float):    
        carreras.append(i.lower())
suma = 0 
       
        
dictIngenieros= {
    "civil informática":0,
    "civil mecánica":0,
    "civil comercial":0,
    "medio ambiente":0,
    "civil":0,
    "civil eléctrica":0
}       
noAsignado =[]

dicCSSoc= {
    "sociología":0,
    "ciencias sociales":0,
    "ciencias políticas":0,
    "arqueología":0,
    "derecho":0,
    "economía":0,
    "psicología":0,
    "pedagogía":0,
    "antropología":0,
    "periodismo":0,
    "historia":0,
    "filosofía":0,
    "literatura":0,
    "política":0,
    "marketing":0, 
    "piloto":0
}


artes={
    "arte":0,
    "teatro":0,
    "arquitectura":0,
    "diseño":0
}



for i in carreras:
    otorgado = False
    if "sociolo" in i:
        dicCarreras["sociología"]+=1
        
        suma+=1
        otorgado = True
        dicCSSoc["sociología"]+=1
    
    if "med" in i or "salud" in i or "méd" in i or "neuro" in i or "obstetricia" in i:
        dicCarreras["medicina"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["medicina"]+=1
        
    if "arte" in i:
        dicCarreras["arte"]+=1
        suma+=1
        otorgado = True
        artes["arte"]+=1
    if "teat" in i or "actu" in i or "actor" in i or "teartro" in i:
        dicCarreras["teatro"]+=1
        suma+=1
        otorgado = True
        artes["teatro"]+=1
    if "vete" in i:
        dicCarreras["veterinaria"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["veterinaria"]+=1
    if "geolo" in i:
        dicCarreras["geologia"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["geologia"]+=1

    if "fís" in i or "fisica" in i:
        dicCarreras["física"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["física"]+=1
    if "social" in i:
        dicCarreras["ciencias sociales"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["ciencias sociales"]+=1
    if "quími" in i:
        dicCarreras["química"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["química"]+=1
    if "arqueo" in i:
        dicCarreras["arqueología"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["arqueología"]+=1
    if "psico" in i:
        dicCarreras["psicología"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["psicología"]+=1
    if "arqui" in i:
        dicCarreras["arquitectura"]+=1
        suma+=1
        otorgado = True
        artes["arquitectura"]+=1
    if "dere" in i or "leyes" in i:
        dicCarreras["derecho"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["derecho"]+=1
    if "econo" in i:
        dicCarreras["economía"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["economía"]+=1
    if "bio" in i:
        dicCarreras["biología"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["biología"]+=1
        
    if "astro" in i:
        dicCarreras["astronomia"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["astronomía"]+=1
    if "enfer" in i:
        dicCarreras["enfermería"]+=1  
        suma+=1
        otorgado = True
        dicSaludYCCNN["enfermería"]+=1
    if "peda" in i:
        dicCarreras["pedagogía"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["pedagogía"]+=1
    if "antrop" in i:
        dicCarreras["antropologia"]+=1 
        suma+=1
        otorgado = True
        dicCSSoc["antropología"]+=1
    if "period" in i:
        dicCarreras["periodismo"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["periodismo"]+=1
    if "hist" in i:
        dicCarreras["historia"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["historia"]+=1
    if "filo" in i:
        dicCarreras["filosofía"]+=1
        suma+=1
        otorgado = True
    if "lit" in i:
        dicCarreras["literatura"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["literatura"]+=1
    if "diseñ" in i:
        dicCarreras["diseño"]+=1
        suma+=1
        otorgado = True
        artes["diseño"]+=1
    if "odonto" in i:
        dicCarreras["odontologia"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["odontología"]+=1
    if "política" in i:
        dicCarreras["ciencias políticas"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["ciencias políticas"]+=1
    if "mark" in i or "nego" in i:
        dicCarreras["marketing"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["marketing"]+=1
    if "nutr" in i:
        dicCarreras["nutrición"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["nutrición"]+=1

    if "pilot" in i:
        dicCarreras["piloto"]+=1
        suma+=1
        otorgado = True
        dicCSSoc["piloto"]+=1
    if "obste" in i:
        dicCarreras["obstetricia"]+=1
        suma+=1
        otorgado = True
        dicSaludYCCNN["obstetricia"]+=1

    if "ingen" in i or "infor" in i or "robo" in i or "softw" in i or "mecan" in i or "program" in i:
        dicCarreras["ingeniería"]+=1
        suma+=1
        otorgado = True
        if "infor" in i or "progra" in i or "compu" in i or "softw" in i:
            dictIngenieros["civil informática"]+=1
        if "mec" in i:
            dictIngenieros["civil mecánica"]+=1
        if "comerc" in i:
            dictIngenieros["civil comercial"]+=1
        if "civil" in i:
            dictIngenieros["civil"]+=1
        if "eléc" in i or "elec" in i or "robo" in i:
            dictIngenieros["civil eléctrica"]+=1
    
    
    if otorgado == False:
        noAsignado.append(i)
     
   

#print(dicCarreras)
#print(dictIngenieros)
#print(len(carreras)) 
#print(suma) 
#print(carreras)
print(noAsignado)

print(        dicSaludYCCNN)

labelsIng=dictIngenieros.keys()
labelsCnn=dicSaludYCCNN.keys()
labelsCSS=dicCSSoc.keys()
labelsArt=artes.keys()

datosIng=[dictIngenieros[key] for key in labelsIng]
datosCnn=[dicSaludYCCNN[key] for key in labelsCnn]
datosCss=[dicCSSoc[key] for key in labelsCSS]
datosArt=[artes[key] for key in labelsArt]


labels = dicCarreras.keys()

datos = [dicCarreras[key] for key in labels]


fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
fig3, ax3 = plt.subplots()
fig4, ax4 = plt.subplots()
fig5, ax5 = plt.subplots()



ax1.pie(datos, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

ax2.title.set_text('Ingenierias')

ax2.pie(datosIng, labels=labelsIng, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax3.title.set_text('CCNN y salud')

ax3.pie(datosCnn, labels=labelsCnn, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax4.title.set_text('CCSS')
ax4.pie(datosCss, labels=labelsCSS, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax5.title.set_text('artes')
ax5.pie(datosArt, labels=labelsArt, autopct='%1.1f%%',
        shadow=True, startangle=90)






plt.show()
# Out:
# ['cosmetica profecional', 'letras inglesas uc', 'castellano', 'decoración de interiores ']
# {'medicina': 25, 'veterinaria': 3, 'geologia': 1, 'química': 4, 'nutrición': 2, 'física': 4, 'biología': 9, 'odontología': 1, 'obstetricia': 1, 'enfermería': 2, 'astronomía': 7}
